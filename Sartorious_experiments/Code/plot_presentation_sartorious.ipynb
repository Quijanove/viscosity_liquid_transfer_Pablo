# %%
# Importing python packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os 

SMALL_SIZE = 16
MEDIUM_SIZE = 20
BIGGER_SIZE = 22

# controls default text sizes
plt.rc('lines',markersize=8)
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=SMALL_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

# %%
# Importing files
REPO = 'viscosity_liquid_transfer_Pablo'
folder = os.getcwd().split(REPO)[0]+REPO+r'\Sartorious_experiments'
std = '204'

# %%
#Load data frame
df_man = pd.read_csv(folder+r'\Cleaned_Data\Viscosity_std_'+std+'_modified.csv')

#Calcualte means
df_duplicates = df_man.where(df_man.duplicated('iteration',keep=False)==True).dropna(how='all')
df_incomplete = df_man.where(df_man.duplicated('iteration',keep=False)==False).dropna(how='all')
df_mean = pd.DataFrame(columns= df_man.columns)

for index,values in df_duplicates.drop_duplicates(['aspiration_rate','dispense_rate']).iterrows():
    if len(df_duplicates.loc[index:index+2]) == 3:
        mean_error =df_duplicates.loc[index:index+2,'%error'].mean()
        df_duplicates.loc[index,'%error'] = mean_error
        df_duplicates.loc[index, 'volume'] ='mean'+str([300, 500, 1000])
        df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
    else:
        df_incomplete = pd.concat([df_incomplete,df_duplicates.loc[index:index+2]]).drop_duplicates()
df_mean = pd.concat([df_mean,df_incomplete])
df_man = df_mean.reset_index(drop=True)   

#Calculate iteration 
counter =1 
for row in df_man.drop_duplicates(['aspiration_rate','dispense_rate']).iterrows():
    df_repeat = df_man.loc[:,['aspiration_rate','dispense_rate']]== row[1].loc[['aspiration_rate','dispense_rate']]
    index = df_repeat.where(df_repeat.sum(axis=1)==2).dropna().index
    df_man.loc[index,'iteration']=counter
    counter+=1
df_man
# Out:
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:14: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_man.loc[index:index+2],df_duplicates.loc[[index]]])
# C:\Users\QUIJAN~1\AppData\Local\Temp/ipykernel_10764/445920632.py:17: FutureWarning: In a future version, object-dtype columns with all-bool values will not be included in reductions with bool_only=True. Explicitly cast to bool dtype instead.
#   df_mean = pd.concat([df_mean,df_incomplete])
#                liquid    pipette                volume  aspiration_rate  \
# 0   Viscosity_std_204  rLine1000                  1000       127.130775
# 1   Viscosity_std_204  rLine1000                   500       127.130775
# 2   Viscosity_std_204  rLine1000                   300       127.130775
# 3   Viscosity_std_204  rLine1000  mean[300, 500, 1000]       127.130775
# 4   Viscosity_std_204  rLine1000                  1000       158.913469
# 5   Viscosity_std_204  rLine1000                   500       158.913469
# 6   Viscosity_std_204  rLine1000                   300       158.913469
# 7   Viscosity_std_204  rLine1000  mean[300, 500, 1000]       158.913469
# 8   Viscosity_std_204  rLine1000                  1000       158.913469
# 9   Viscosity_std_204  rLine1000                   500       158.913469
# 10  Viscosity_std_204  rLine1000                   300       158.913469
# 11  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       158.913469
# 12  Viscosity_std_204  rLine1000                  1000        12.713078
# 13  Viscosity_std_204  rLine1000                   500        12.713078
# 14  Viscosity_std_204  rLine1000                   300        12.713078
# 15  Viscosity_std_204  rLine1000  mean[300, 500, 1000]        12.713078
# 16  Viscosity_std_204  rLine1000                  1000        12.713078
# 17  Viscosity_std_204  rLine1000                   500        12.713078
# 18  Viscosity_std_204  rLine1000                   300        12.713078
# 19  Viscosity_std_204  rLine1000  mean[300, 500, 1000]        12.713078
# 20  Viscosity_std_204  rLine1000                  1000       150.000000
# 21  Viscosity_std_204  rLine1000                   500       150.000000
# 22  Viscosity_std_204  rLine1000                   300       150.000000
# 23  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       150.000000
# 24  Viscosity_std_204  rLine1000                   500       150.000000
# 25  Viscosity_std_204  rLine1000                  1000       150.000000
# 26  Viscosity_std_204  rLine1000                   300       150.000000
# 27  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       150.000000
# 28  Viscosity_std_204  rLine1000                  1000       170.000000
# 29  Viscosity_std_204  rLine1000                   500       170.000000
# 30  Viscosity_std_204  rLine1000                   300       170.000000
# 31  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       170.000000
# 32  Viscosity_std_204  rLine1000                  1000       170.000000
# 33  Viscosity_std_204  rLine1000                   500       170.000000
# 34  Viscosity_std_204  rLine1000                   300       170.000000
# 35  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       170.000000
# 36  Viscosity_std_204  rLine1000                  1000       200.000000
# 37  Viscosity_std_204  rLine1000                   500       200.000000
# 38  Viscosity_std_204  rLine1000                   300       200.000000
# 39  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       200.000000
# 40  Viscosity_std_204  rLine1000                  1000       185.000000
# 41  Viscosity_std_204  rLine1000                   500       185.000000
# 42  Viscosity_std_204  rLine1000                   300       185.000000
# 43  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       185.000000
# 44  Viscosity_std_204  rLine1000                  1000       190.000000
# 45  Viscosity_std_204  rLine1000                   500       190.000000
# 46  Viscosity_std_204  rLine1000                   300       190.000000
# 47  Viscosity_std_204  rLine1000  mean[300, 500, 1000]       190.000000
#
#     dispense_rate blow_out delay_aspirate delay_dispense delay_blow_out  \
# 0      127.130775    False             10             10              0
# 1      127.130775    False             10             10              0
# 2      127.130775    False             10             10              0
# 3      127.130775    False             10             10              0
# 4      158.913469    False             10             10              0
# 5      158.913469    False             10             10              0
# 6      158.913469    False             10             10              0
# 7      158.913469    False             10             10              0
# 8       12.713078    False             10             10              0
# 9       12.713078    False             10             10              0
# 10      12.713078    False             10             10              0
# 11      12.713078    False             10             10              0
# 12     158.913469    False             10             10              0
# 13     158.913469    False             10             10              0
# 14     158.913469    False             10             10              0
# 15     158.913469    False             10             10              0
# 16      12.713078    False             10             10              0
# 17      12.713078    False             10             10              0
# 18      12.713078    False             10             10              0
# 19      12.713078    False             10             10              0
# 20      15.000000    False             10             10              0
# 21      15.000000    False             10             10              0
# 22      15.000000    False             10             10              0
# 23      15.000000    False             10             10              0
# 24      20.000000    False             10             10              0
# 25      20.000000    False             10             10              0
# 26      20.000000    False             10             10              0
# 27      20.000000    False             10             10              0
# 28      15.000000    False             10             10              0
# 29      15.000000    False             10             10              0
# 30      15.000000    False             10             10              0
# 31      15.000000    False             10             10              0
# 32      18.000000    False             10             10              0
# 33      18.000000    False             10             10              0
# 34      18.000000    False             10             10              0
# 35      18.000000    False             10             10              0
# 36      18.000000    False             10             10              0
# 37      18.000000    False             10             10              0
# 38      18.000000    False             10             10              0
# 39      18.000000    False             10             10              0
# 40      18.000000    False             10             10              0
# 41      18.000000    False             10             10              0
# 42      18.000000    False             10             10              0
# 43      18.000000    False             10             10              0
# 44      18.000000    False             10             10              0
# 45      18.000000    False             10             10              0
# 46      18.000000    False             10             10              0
# 47      18.000000    False             10             10              0
#
#     density        time         m     %error Transfer_Observation  \
# 0    0.8639   78.725538  0.758603 -12.188579    Complete Transfer
# 1    0.8639   71.047900  0.402936  -6.717021    Complete Transfer
# 2    0.8639   67.998543  0.238253  -8.070855    Complete Transfer
# 3    0.8639   78.725538  0.758603  -8.992152    Complete Transfer
# 4    0.8639   75.887200  0.682425 -21.006491    Complete Transfer
# 5    0.8639   69.869834  0.394674  -8.629705    Complete Transfer
# 6    0.8639   67.242198  0.222603 -14.109134    Complete Transfer
# 7    0.8639   75.887200  0.682425 -14.581777    Complete Transfer
# 11  Blowout before         3     104.951893
# 12  Blowout before         4     104.951893
# 13  Blowout before         4     104.951893
# 14  Blowout before         4     104.951893
# 15  Blowout before         4     104.951893
# 16  Blowout before         5     177.318320
# 17  Blowout before         5     177.318320
# 18  Blowout before         5     177.318320
# 19  Blowout before         5     177.318320
# 20  Blowout before         6      93.333333
# 21  Blowout before         6      93.333333
# 22  Blowout before         6      93.333333
# 23  Blowout before         6      93.333333
# 24  Blowout before         7      76.666667
# 25  Blowout before         7      76.666667
# 26  Blowout before         7      76.666667
# 27  Blowout before         7      76.666667
# 28  Blowout before         8      92.549020
# 29  Blowout before         8      92.549020
# 30  Blowout before         8      92.549020
# 31  Blowout before         8      92.549020
# 32  Blowout before         9      81.437909
# 33  Blowout before         9      81.437909
# 34  Blowout before         9      81.437909
# 35  Blowout before         9      81.437909
# 36  Blowout before        10      80.555556
# 37  Blowout before        10      80.555556
# 38  Blowout before        10      80.555556
# 39  Blowout before        10      80.555556
# 40  Blowout before        11      80.960961
# 41  Blowout before        11      80.960961
# 42  Blowout before        11      80.960961
# 43  Blowout before        11      80.960961
# 44  Blowout before        12      80.818713
# 45  Blowout before        12      80.818713
# 46  Blowout before        12      80.818713
# 47  Blowout before        12      80.818713

# %%
#Load dataframe
df_exp2 = pd.read_csv(folder+r'\Code\Viscosity_std_'+std+'_BOTorch_exp2.csv')

#Calculate iterations
counter =1 
for i in range(0,len(df_exp2)+1,3):
    if len(df_exp2.loc[i:i+2,'volume'].drop_duplicates())==1:
        df_exp2.loc[i,'iteration']=counter
        counter+=1    
        df_exp2.loc[i+1,'iteration']=counter
        counter+=1  
        df_exp2.loc[i+2,'iteration']=counter
        counter+=1          
    else:
        df_exp2.loc[i:i+2,'iteration']=counter
        counter+=1

# %%
#Load data frame
# df_exp3 = pd.read_csv(folder+r'\Experimental_Data\Batch_optimization_data\BOTorch\MOBO\Viscosity_std_'+std+'_BOTorch_exp3.csv')
df_exp3= pd.read_csv(r'C:\Users\quijanovelascop\OneDrive - A STAR\Documents\GitHub\viscosity_liquid_transfer_Pablo\full_auto_204.csv')
df_exp3 = df_exp3.drop('Unnamed: 0', axis=1)
#Calculate iteration number
counter =1 
for row in df_exp3.drop_duplicates(['aspiration_rate','dispense_rate']).iterrows():
    df_repeat = df_exp3.loc[:,['aspiration_rate','dispense_rate']]== row[1].loc[['aspiration_rate','dispense_rate']]
    index = df_repeat.where(df_repeat.sum(axis=1)==2).dropna().index
    df_exp3.loc[index,'iteration']=counter
    counter+=1

#Edit volumes to be all the same 
volumes = ['1000.0','500.0','300.0']
for volume in volumes:
    index = df_exp3.where(df_exp3.volume==volume).dropna(how='all').index
    df_exp3.loc[index,'volume'] = volume[:-2]


df_exp3
# Out:
#              liquid    pipette                volume  aspiration_rate  \
# 0   Viscous_std_204  rLine1000                  1000       179.460000
# 1   Viscous_std_204  rLine1000                   500       179.460000
# 2   Viscous_std_204  rLine1000                   300       179.460000
# 3   Viscous_std_204  rLine1000  mean[300, 500, 1000]       179.460000
# 4   Viscous_std_204  rLine1000                  1000       224.325000
# 5   Viscous_std_204  rLine1000                   500       224.325000
# 6   Viscous_std_204  rLine1000                   300       224.325000
# 7   Viscous_std_204  rLine1000  mean[300, 500, 1000]       224.325000
# 8   Viscous_std_204  rLine1000                  1000       224.325000
# 9   Viscous_std_204  rLine1000                   500       224.325000
# 10  Viscous_std_204  rLine1000                   300       224.325000
# 11  Viscous_std_204  rLine1000  mean[300, 500, 1000]       224.325000
# 12  Viscous_std_204  rLine1000                  1000        17.946000
# 13  Viscous_std_204  rLine1000                   500        17.946000
# 14  Viscous_std_204  rLine1000                   300        17.946000
# 15  Viscous_std_204  rLine1000  mean[300, 500, 1000]        17.946000
# 16  Viscous_std_204  rLine1000                  1000        17.946000
# 17  Viscous_std_204  rLine1000                   500        17.946000
# 18  Viscous_std_204  rLine1000                   300        17.946000
# 19  Viscous_std_204  rLine1000  mean[300, 500, 1000]        17.946000
# 20  Viscous_std_204  rLine1000                  1000       164.952908
# 21  Viscous_std_204  rLine1000                   500       164.952908
# 22  Viscous_std_204  rLine1000                   300       164.952908
# 23  Viscous_std_204  rLine1000  mean[300, 500, 1000]       164.952908
# 24  Viscous_std_204  rLine1000                  1000       154.768720
# 25  Viscous_std_204  rLine1000                   500       154.768720
# 26  Viscous_std_204  rLine1000                   300       154.768720
# 27  Viscous_std_204  rLine1000  mean[300, 500, 1000]       154.768720
# 28  Viscous_std_204  rLine1000                  1000        98.126213
# 29  Viscous_std_204  rLine1000                   500        98.126213
# 30  Viscous_std_204  rLine1000                   300        98.126213
# 31  Viscous_std_204  rLine1000  mean[300, 500, 1000]        98.126213
# 32  Viscous_std_204  rLine1000                  1000        71.656261
# 33  Viscous_std_204  rLine1000                   500        71.656261
# 34  Viscous_std_204  rLine1000                   300        71.656261
# 35  Viscous_std_204  rLine1000  mean[300, 500, 1000]        71.656261
# 36  Viscous_std_204  rLine1000                  1000        86.673001
# 37  Viscous_std_204  rLine1000                   500        86.673001
# 38  Viscous_std_204  rLine1000                   300        86.673001
# 39  Viscous_std_204  rLine1000  mean[300, 500, 1000]        86.673001
#
#     dispense_rate  blow_out  delay_aspirate  delay_dispense  delay_blow_out  \
# 0      179.460000     False              10              10               0
# 1      179.460000     False              10              10               0
# 2      179.460000     False              10              10               0
# 3      179.460000     False              10              10               0
# 4      224.325000     False              10              10               0
# 5      224.325000     False              10              10               0
# 6      224.325000     False              10              10               0
# 7      224.325000     False              10              10               0
# 8       17.946000     False              10              10               0
# 9       17.946000     False              10              10               0
# 10      17.946000     False              10              10               0
# 11      17.946000     False              10              10               0
# 12     224.325000     False              10              10               0
# 13     224.325000     False              10              10               0
# 14     224.325000     False              10              10               0
# 15     224.325000     False              10              10               0
# 16      17.946000     False              10              10               0
# 17      17.946000     False              10              10               0
# 18      17.946000     False              10              10               0
# 19      17.946000     False              10              10               0
# 20      63.455079     False              10              10               0
# 21      63.455079     False              10              10               0
# 22      63.455079     False              10              10               0
# 23      63.455079     False              10              10               0
# 24      23.435888     False              10              10               0
# 25      23.435888     False              10              10               0
# 26      23.435888     False              10              10               0
# 27      23.435888     False              10              10               0
# 28      46.161417     False              10              10               0
# 29      46.161417     False              10              10               0
# 30      46.161417     False              10              10               0
# 0         1.0
# 1         1.0
# 2         1.0
# 3         1.0
# 4         2.0
# 5         2.0
# 6         2.0
# 7         2.0
# 8         3.0
# 9         3.0
# 10        3.0
# 11        3.0
# 12        4.0
# 13        4.0
# 14        4.0
# 15        4.0
# 16        5.0
# 17        5.0
# 18        5.0
# 19        5.0
# 20        6.0
# 21        6.0
# 22        6.0
# 23        6.0
# 24        7.0
# 25        7.0
# 26        7.0
# 27        7.0
# 28        8.0
# 29        8.0
# 30        8.0
# 31        8.0
# 32        9.0
# 33        9.0
# 34        9.0
# 35        9.0
# 36       10.0
# 37       10.0
# 38       10.0
# 39       10.0

# %% [markdown]
# #### Plot for exp2 and manual calibration

# %%
#Makes a figure with manual and ML calibrations, one per volume

for volume in [1000,500,300]:
    df_exp2_plot = df_exp2.where(df_exp2.volume==volume).dropna(how='all').copy()
    df_man_plot = df_man.where(df_man.volume==volume).dropna(how='all').copy()
    #Making subplots (2 rows, 1 column)
    fig,axs = plt.subplots(1,2)

    # Plotting graph 1: Iteration against error
    if volume == 1000:
        color = 'red'
    elif volume== 500:
        color = 'green'
    elif volume ==300:
        color = 'black'    
    
    if len(df_man) != 0:
        axs.flatten()[0].scatter(df_man_plot['iteration'],df_man_plot['%error'], marker= 'o', label = str(volume)+u' \u03bcL', c = color)
        axs.flatten()[0].plot(df_man_plot['iteration'],df_man_plot['%error'], label = 'Human Driven', c = 'cornflowerblue')
   
    if len(df_exp2) != 0:
        axs.flatten()[0].scatter(df_exp2_plot['iteration'],df_exp2_plot['%error'], marker= 'o', c = color)
        axs.flatten()[0].plot(df_exp2_plot['iteration'],df_exp2_plot['%error'], label = 'ML Driven', c = 'orangered')
    
    
    axs.flatten()[0].axhline(y=0, ls = '--', color = 'black', linewidth=0.5)
    axs.flatten()[0].axhline(y=2.5, ls = '--', color = 'black', linewidth=0.5)
    axs.flatten()[0].axhline(y=-2.5, ls = '--', color = 'black', linewidth=0.5)
    axs.flatten()[0].set_xlabel('Iteration')
    axs.flatten()[0].set_ylabel('Error [%]')



    axs.flatten()[1].scatter(df_exp2_plot['iteration'],df_exp2_plot['time_asp_1000'], marker= 'o', c = color)
    axs.flatten()[1].plot(df_exp2_plot['iteration'],df_exp2_plot['time_asp_1000'],  c = 'orangered')

    axs.flatten()[1].scatter(df_man_plot['iteration'],df_man_plot['time_for_1000'], marker= 'o', c = color)
    axs.flatten()[1].plot(df_man_plot['iteration'],df_man_plot['time_for_1000'], c = 'cornflowerblue')


    axs.flatten()[1].set_xlabel('Iteration')
    axs.flatten()[1].set_ylabel('Time for 1000ul (s)')

    fig.set_size_inches(15, 4)
    fig.suptitle('Viscosity_std_'+std+'_'+'_exp2_CCF_initialisation')
    fig.legend(bbox_to_anchor=(0., 1.02, 1., .102), loc='lower left',ncol=5, mode="expand", borderaxespad=0.)
    fig.tight_layout()

    REPO = 'viscosity_liquid_transfer_Pablo'
    folder = os.getcwd().split(REPO)[0]+REPO+r'\Sartorious_experiments\Finalised_Data'
    fig.savefig(folder+r'/'+'Viscosity_std_'+std+'_'+str(volume)+'_exp2_line.png')

# %%
df_exp3=df_exp3[:40]
# df_man=df_man[:40]

# %%
#Making subplots (2 rows, 2 column)
fig,axs = plt.subplots(2,1,sharex=True)

# Dropping NAN rows
df_man_1000 = df_man.where(df_man.volume.astype('str')=='1000').dropna(how='all')
df_man_500 = df_man.where(df_man.volume.astype('str')=='500').dropna(how='all')
df_man_300 = df_man.where(df_man.volume.astype('str')=='300').dropna(how='all')
df_man_100 = df_man.where(df_man.volume.astype('str')=='10.0.0').dropna(how='all')
df_man_mean = df_man.where(df_man.volume=='mean[300, 500, 1000]').dropna(how='all')


df_exp3_1000 = df_exp3.where(df_exp3.volume=='1000').dropna(how='all')
df_exp3_500 = df_exp3.where(df_exp3.volume=='500').dropna(how='all')
df_exp3_300 = df_exp3.where(df_exp3.volume=='300').dropna(how='all')
df_exp3_100 = df_exp3.where(df_exp3.volume=='100').dropna(how='all')
df_exp3_mean = df_exp3.where(df_exp3.volume=='mean[300, 500, 1000]').dropna(how='all')

#find min error

df_exp3_mean_min_iteration = df_exp3_mean.loc[20:].copy()[['iteration','%error']].abs().sort_values('%error').iloc[0,0]
df_man_mean_min_iteration = df_man_mean.loc[20:].copy()[['iteration','%error']].abs().sort_values('%error').iloc[0,0]

#make new dataframes with minimimum mean error values for manual calibration data
df_man_min_1000 = pd.DataFrame()
df_man_min_1000 = df_man_1000[df_man_1000['iteration'] == df_man_mean_min_iteration].dropna(how='all')
df_man_min_500 = pd.DataFrame()
df_man_min_500 = df_man_500[df_man_500['iteration'] == df_man_mean_min_iteration].dropna(how='all')
df_man_min_300 = pd.DataFrame()
df_man_min_300 = df_man_300[df_man_300['iteration'] == df_man_mean_min_iteration].dropna(how='all')


#make new dataframes with minimimum mean error values for exp3 data
df_exp3_min_1000 = pd.DataFrame()
df_exp3_min_1000 = df_exp3_1000[df_exp3_1000['iteration'] == df_exp3_mean_min_iteration].dropna(how='all')
df_exp3_min_500 = pd.DataFrame()
df_exp3_min_500 = df_exp3_500[df_exp3_500['iteration'] == df_exp3_mean_min_iteration].dropna(how='all')
df_exp3_min_300 = pd.DataFrame()
df_exp3_min_300 = df_exp3_300[df_exp3_300['iteration'] == df_exp3_mean_min_iteration].dropna(how='all')


# Plotting graph 1: Iteration against error
if len(df_man_mean) != 0:
    axs.flatten()[0].plot(df_man_mean['iteration'],df_man_mean['%error'],marker= 'o', label = 'Human Driven mean', c = 'cornflowerblue')


if len(df_exp3_mean) != 0:
    axs.flatten()[0].plot(df_exp3_mean['iteration'],df_exp3_mean['%error'],marker= 'o', label='ML Driven mean',c = 'orangered')

if len(df_man_min_1000) != 0:
    axs.flatten()[0].plot(df_man_min_1000['iteration'],df_man_min_1000['%error'], marker= 'x', label = '1000 μL',  c = 'red',linestyle="None")
    

if len(df_man_min_500) != 0:
    axs.flatten()[0].plot(df_man_min_500['iteration'],df_man_min_500['%error'], marker= 'x', label = '500 μL', c = 'green',linestyle="None")

if len(df_man_min_300) != 0:
    axs.flatten()[0].plot(df_man_min_300['iteration'],df_man_min_300['%error'], marker= 'x', label = '300 μL', c = 'black',linestyle="None")


if len(df_exp3_min_1000) != 0:
    axs.flatten()[0].plot(df_exp3_min_1000['iteration'],df_exp3_min_1000['%error'], marker= 'x', c = 'red',linestyle="None")

if len(df_exp3_min_500) != 0:
    axs.flatten()[0].plot(df_exp3_min_500['iteration'],df_exp3_min_500['%error'], marker= 'x', c = 'green',linestyle="None")

if len(df_exp3_min_300) != 0:
    axs.flatten()[0].plot(df_exp3_min_300['iteration'],df_exp3_min_300['%error'], marker= 'x', c = 'black',linestyle="None")

for i in range(len(axs.flatten())-1):
    axs.flatten()[i].axhline(y=0, color = 'black', linewidth=1)
    axs.flatten()[i].axhline(y=5, ls = '--', color = 'black', linewidth=0.75)
    axs.flatten()[i].axhline(y=-5, ls = '--', color = 'black', linewidth=0.75)
    # axs.flatten()[i].set_xlabel('Iteration')
    axs.flatten()[i].set_ylabel('Mean percent error''\n''of transfer [%]')
    


axs.flatten()[1].plot(df_man_mean['iteration'],df_man_1000['time_for_1000'], marker= 'o', c = 'cornflowerblue')

if len(df_exp3_mean) != 0:
    axs.flatten()[1].plot(df_exp3_mean['iteration'],df_exp3_mean['time_asp_1000'], marker ='o', c = 'orangered')

axs.flatten()[0].set_yticks((np.arange(df_exp3_mean['%error'].min()-df_exp3_mean['%error'].min()%5,12,5)))
axs.flatten()[1].set_xlabel('Iteration')
axs.flatten()[1].set_ylabel('Time to transfer ''\n''1000 μL [s]')
axs.flatten()[1].set_xticks(np.arange(1,11,1))

fig.set_size_inches(8,8)
# fig.suptitle('Viscosity standard '+str(std)+ 'cp batch volume optimization')
fig.tight_layout(pad=2)
#fig.legend( loc='lower center',ncol=5, borderaxespad=-0.2)

xmargin = .15
ymargin = .5

man_best_iter = df_man_mean_min_iteration
exp3_best_iter = df_exp3_mean_min_iteration

df_man_box = df_man[df_man['iteration'] == man_best_iter]

man_min_f0, man_max_f0 = min(df_man_box['iteration']) - xmargin, max(df_man_box['iteration']) + xmargin
man_min_f1, man_max_f1 = min(df_man_box['%error']) - ymargin, max(df_man_box['%error']) + ymargin

man_width = man_max_f0 - man_min_f0
man_height = man_max_f1 - man_min_f1

import matplotlib.patches as patches

axs[0].add_patch(
    patches.Rectangle(
        xy=(man_min_f0, man_min_f1),  # point of origin.
        width=man_width, height=man_height, linewidth=2,
        color='cornflowerblue', fill=False))

df_exp3_box = df_exp3[df_exp3['iteration'] == exp3_best_iter]

exp3_min_f0, exp3_max_f0 = min(df_exp3_box['iteration']) - xmargin, max(df_exp3_box['iteration']) + xmargin
exp3_min_f1, exp3_max_f1 = min(df_exp3_box['%error']) - ymargin, max(df_exp3_box['%error']) + ymargin

exp3_width = exp3_max_f0 - exp3_min_f0
exp3_height = exp3_max_f1 - exp3_min_f1


axs[0].add_patch(
    patches.Rectangle(
        xy=(exp3_min_f0, exp3_min_f1),  # point of origin.
        width=exp3_width, height=exp3_height, linewidth=2,
        color='orangered', fill=False))

# fig.suptitle('Viscosity standard '+str(std)+ 'cp batch volume optimization')

# REPO = 'viscosity_liquid_transfer_Pablo'
# folder = os.getcwd().split(REPO)[0]+REPO+r'\Sartorious_experiments\Finalised_Data'
# fig.savefig(folder+r'/'+'Viscosity_std_'+std+'_exp3_line.png')
