# %% [markdown]
# # Sartorious Initialisation Data Code

# %%
# Importing packages
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import os 

# Importing files
std = '817'
folder = (r"C:\Users\admin\Documents\GitHub\viscosity_liquid_transfer_Pablo\Sartorious_experiments\Cleaned_Data")

df = pd.read_csv(folder+r'/Viscosity_std_'+std+'_modified.csv')

df
# Out:
#                liquid    pipette  volume  aspiration_rate  dispense_rate  \
# 0   Viscosity_std_817  rLine1000  1000.0        54.163119      54.163119
# 1   Viscosity_std_817  rLine1000   500.0        54.163119      54.163119
# 2   Viscosity_std_817  rLine1000   300.0        54.163119      54.163119
# 3   Viscosity_std_817  rLine1000  1000.0        54.163119      40.000000
# 4   Viscosity_std_817  rLine1000   500.0        54.163119      40.000000
# 5   Viscosity_std_817  rLine1000   300.0        54.163119      40.000000
# 6   Viscosity_std_817  rLine1000  1000.0        50.000000      40.000000
# 7   Viscosity_std_817  rLine1000   500.0        50.000000      40.000000
# 8   Viscosity_std_817  rLine1000   300.0        50.000000      40.000000
# 9   Viscosity_std_817  rLine1000  1000.0        30.000000      40.000000
# 10  Viscosity_std_817  rLine1000   500.0        30.000000      40.000000
# 11  Viscosity_std_817  rLine1000   300.0        30.000000      40.000000
# ...

# %%
#Slicing the dataframe (just need the first 15 values of blowout before)
df_init = df.loc[0:14 , :]
df_init
# Out:
#                liquid    pipette  volume  aspiration_rate  dispense_rate  \
# 0   Viscosity_std_398  rLine1000  1000.0       181.315742     181.315742
# 1   Viscosity_std_398  rLine1000   500.0       181.315742     181.315742
# 2   Viscosity_std_398  rLine1000   300.0       181.315742     181.315742
# 3   Viscosity_std_398  rLine1000  1000.0       226.644678     226.644678
# 4   Viscosity_std_398  rLine1000   500.0       226.644678     226.644678
# 5   Viscosity_std_398  rLine1000   300.0       226.644678     226.644678
# 6   Viscosity_std_398  rLine1000  1000.0        18.131574     226.644678
# 7   Viscosity_std_398  rLine1000   500.0        18.131574     226.644678
# 8   Viscosity_std_398  rLine1000   300.0        18.131574     226.644678
# 9   Viscosity_std_398  rLine1000  1000.0       226.644678      18.131574
# 10  Viscosity_std_398  rLine1000   500.0       226.644678      18.131574
# 11  Viscosity_std_398  rLine1000   300.0       226.644678      18.131574
# ...

# %%
# Standardising column names (by renaming/making new columns)
df_init.rename(columns={"time_for_1000" : "time_asp_1000"}, inplace=True)
df_init['acq_value'] = "None"
df_init
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:5039: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# C:\Users\admin\AppData\Local\Temp\ipykernel_14652\268068696.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_init['acq_value'] = "None"
#                liquid    pipette  volume  aspiration_rate  dispense_rate  \
# 0   Viscosity_std_398  rLine1000  1000.0       181.315742     181.315742
# 1   Viscosity_std_398  rLine1000   500.0       181.315742     181.315742
# ...

# %%
#Initialisation data file as per Anne's viscosity_std files
folder = (r"C:\Users\admin\Documents\GitHub\viscosity_liquid_transfer_Pablo\Sartorious_experiments\Initialisation_Data")
df_init.to_csv(folder+r'/'+'Initialisation_'+std+'.csv', index=False)

# %%
# #Initialisation data file as per Anne's viscosity_std_curated files
# df_init.drop(columns=['time', 'm', '%error', 'Transfer_Observation', 'Comment', 'iteration'], inplace=True)
# folder = (r"C:\Users\admin\Documents\GitHub\viscosity_liquid_transfer_Pablo\Sartorious_experiments\Initialisation_Data")
# df_init.to_csv(folder+r'/'+'Initialisation_'+std+'_curated.csv', index=False)
# df_init
# Out:
# C:\Users\admin\AppData\Roaming\Python\Python311\site-packages\pandas\core\frame.py:4906: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(
#                 liquid    pipette  volume  aspiration_rate  dispense_rate  \
# 0   Viscosity_std_1275  rLine1000  1000.0        28.915134      28.915134
# 1   Viscosity_std_1275  rLine1000   500.0        28.915134      28.915134
# 2   Viscosity_std_1275  rLine1000   300.0        28.915134      28.915134
# 3   Viscosity_std_1275  rLine1000  1000.0        36.143918      36.143918
# 4   Viscosity_std_1275  rLine1000   500.0        36.143918      36.143918
# 5   Viscosity_std_1275  rLine1000   300.0        36.143918      36.143918
# 6   Viscosity_std_1275  rLine1000  1000.0         2.891513      36.143918
# ...
