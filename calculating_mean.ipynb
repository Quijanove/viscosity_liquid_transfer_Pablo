# %%
import numpy as np
import pandas as pd

# %%
# def calc_stats(file_path):    
    # df_experiment = pd.read_csv(r"C:\Users\amdm_\Documents\GitHub\viscosity_liquid_transfer_Pablo\Sartorious_experiments\Experimental_Data\Best_parameters_data\Batch_optimization\Viscosity_std_817_BP_exp3.csv", header=0)
df_experiment = pd.read_csv(r'Opentrons_experiments\BOTorch_optimization\Viscosity_std_1275_calibration_2.csv', header=0)
df_experiment
calibration_summary(df_experiment)
# Out:
#                     Mean transfer volume for 1000.0 µL [µL]  \
# Viscosity_std_1275                               986.343864
#
#                     Mean transfer volume error of 1000.0 µL [µL]  \
# Viscosity_std_1275                                    -13.656136
#
#                     Mean relative error for transfer of 1000.0 µL [%]  \
# Viscosity_std_1275                                          -1.365614
#
#                     Standard deviation for transfer of 1000.0 µL [µL]  \
# Viscosity_std_1275                                             8.3989
#
#                     Relative standard deviation for transfer of 1000.0 µL [%]  \
# Viscosity_std_1275                                           0.851518
#
#                     Mean transfer volume for 500.0 µL [µL]  \
# Viscosity_std_1275                              487.419872
#
#                     Mean transfer volume error of 500.0 µL [µL]  \
# Viscosity_std_1275                                   -12.580128
#
#                     Mean relative error for transfer of 500.0 µL [%]  \
# Viscosity_std_1275                                         -2.516026
#
#                     Standard deviation for transfer of 500.0 µL [µL]  \
# Viscosity_std_1275                                          4.831993
#
#                     Relative standard deviation for transfer of 500.0 µL [%]  \
# Viscosity_std_1275                                           0.991341
#
#                     Mean transfer volume for 300.0 µL [µL]  \
# Viscosity_std_1275                              283.184524
#
#                     Mean transfer volume error of 300.0 µL [µL]  \
# Viscosity_std_1275                                   -16.815476
#
#                     Mean relative error for transfer of 300.0 µL [%]  \
# Viscosity_std_1275                                         -5.605159
#
#                     Standard deviation for transfer of 300.0 µL [µL]  \
# Viscosity_std_1275                                          3.416831
#
#                     Relative standard deviation for transfer of 300.0 µL [%]
# Viscosity_std_1275                                           1.206574

# %%
df_experiment["act_volume"] = (df_experiment["m"] / df_experiment["density"] * 1000)
df_experiment["abs_error"] = (df_experiment["volume"] - df_experiment["act_volume"])
df_experiment["act_time"] = ((df_experiment["volume"] / df_experiment["aspiration_rate"]) + (df_experiment["volume"] / df_experiment["dispense_rate"]) + df_experiment["delay_aspirate"] + df_experiment["delay_dispense"])
df_experiment["percent_error"] = (df_experiment["abs_error"] /(df_experiment["volume"]/100) )
df_experiment
# Out:
#     Unnamed: 0             liquid pipette  volume  aspiration_rate  \
# 0            0  Viscosity_std_204   p1000  1000.0       105.261855
# 1            1  Viscosity_std_204   p1000  1000.0       105.261855
# 2            2  Viscosity_std_204   p1000  1000.0       105.261855
# 3            3  Viscosity_std_204   p1000  1000.0       105.261855
# 4            4  Viscosity_std_204   p1000  1000.0       105.261855
# 5            5  Viscosity_std_204   p1000  1000.0       105.261855
# 6            6  Viscosity_std_204   p1000  1000.0       105.261855
# 7            7  Viscosity_std_204   p1000  1000.0       105.261855
# 8            8  Viscosity_std_204   p1000  1000.0       105.261855
# 9            9  Viscosity_std_204   p1000  1000.0       105.261855
# 10          10  Viscosity_std_204   p1000   500.0       105.261855
# 11          11  Viscosity_std_204   p1000   500.0       105.261855
# 12          12  Viscosity_std_204   p1000   500.0       105.261855
# 13          13  Viscosity_std_204   p1000   500.0       105.261855
# 14          14  Viscosity_std_204   p1000   500.0       105.261855
# 15          15  Viscosity_std_204   p1000   500.0       105.261855
# 16          16  Viscosity_std_204   p1000   500.0       105.261855
# 17          17  Viscosity_std_204   p1000   500.0       105.261855
# 18          18  Viscosity_std_204   p1000   500.0       105.261855
# 19          19  Viscosity_std_204   p1000   500.0       105.261855
# 20          20  Viscosity_std_204   p1000   300.0       105.261855
# 21          21  Viscosity_std_204   p1000   300.0       105.261855
# 22          22  Viscosity_std_204   p1000   300.0       105.261855
# 23          23  Viscosity_std_204   p1000   300.0       105.261855
# 24          24  Viscosity_std_204   p1000   300.0       105.261855
# 25          25  Viscosity_std_204   p1000   300.0       105.261855
# 26          26  Viscosity_std_204   p1000   300.0       105.261855
# 27          27  Viscosity_std_204   p1000   300.0       105.261855
# 28          28  Viscosity_std_204   p1000   300.0       105.261855
# 29          29  Viscosity_std_204   p1000   300.0       105.261855
#
#     dispense_rate  blow_out_rate  delay_aspirate  delay_dispense  \
# 0        22.65554              0               5               5
# 1        22.65554              0               5               5
# 2        22.65554              0               5               5
# 3        22.65554              0               5               5
# 4        22.65554              0               5               5
# 5        22.65554              0               5               5
# 6        22.65554              0               5               5
# 7        22.65554              0               5               5
# 8        22.65554              0               5               5
# 9        22.65554              0               5               5
# 10       22.65554              0               5               5
# 11       22.65554              0               5               5
# 12       22.65554              0               5               5
# 13       22.65554              0               5               5
# 14       22.65554              0               5               5
# 15       22.65554              0               5               5
# 16       22.65554              0               5               5
# 17       22.65554              0               5               5
# 18       22.65554              0               5               5
# 19       22.65554              0               5               5
# 20       22.65554              0               5               5
# 21       22.65554              0               5               5
# 22       22.65554              0               5               5
# 23       22.65554              0               5               5
# 24       22.65554              0               5               5
# 25       22.65554              0               5               5
# 26       22.65554              0               5               5
# 27       22.65554              0               5               5
# 28       22.65554              0               5               5
# 29       22.65554              0               5               5
#
#     delay_blow_out  ...       mi       mf       m    %error  \
# 0                0  ...  21.2268  22.0838  0.8570 -0.798704
# 1                0  ...  22.0838  22.9367  0.8529 -1.273296
# 2                0  ...  22.9367  23.8068  0.8701  0.717676
# 3                0  ...  23.8068  24.6728  0.8660  0.243084
# 4                0  ...  24.6728  25.5429  0.8701  0.717676
# 5                0  ...  25.5429  26.4125  0.8696  0.659799
# 6                0  ...  26.4125  27.2815  0.8690  0.590346
# 7                0  ...  27.2815  28.1501  0.8686  0.544044
# 8                0  ...  28.1501  29.0198  0.8697  0.671374
# 9                0  ...  29.0198  29.8867  0.8669  0.347262
# 10               0  ...  29.8867  30.3272  0.4405  1.979396
# 11               0  ...  30.3272  30.7643  0.4371  1.192268
# 12               0  ...  30.7643  31.2002  0.4359  0.914458
# 13               0  ...  31.2002  31.6358  0.4356  0.845005
# 14               0  ...  31.6358  32.0516  0.4158 -3.738859
# 15               0  ...  32.0516  32.4801  0.4285 -0.798704
# 16               0  ...  32.4801  32.9002  0.4201 -2.743373
# 17               0  ...  32.9002  33.3321  0.4319 -0.011575
# 18               0  ...  33.3321  33.7605  0.4284 -0.821854
# 19               0  ...  33.7605  34.1935  0.4330  0.243084
# 20               0  ...  21.1160  21.3776  0.2616  0.937609
# 21               0  ...  21.3776  21.6443  0.2667  2.905429
# 22               0  ...  21.6443  21.9106  0.2663  2.751090
# 23               0  ...  21.9106  22.1765  0.2659  2.596751
# 24               0  ...  22.1765  22.4424  0.2659  2.596751
# 25               0  ...  22.4424  22.7072  0.2648  2.172319
# 26               0  ...  22.7072  22.9747  0.2675  3.214107
# 27               0  ...  22.9747  23.2408  0.2661  2.673921
# 28               0  ...  23.2408  23.5062  0.2654  2.403828
# 29               0  ...  23.5062  23.7701  0.2639  1.825057
#
#     Transfer_Observation  Comment   act_volume  abs_error   act_time  \
# 0       Within Tolerance      NaN   992.012964   7.987036  63.639432
# 1       Within Tolerance      NaN   987.267045  12.732955  63.639432
# 2       Within Tolerance      NaN  1007.176757  -7.176757  63.639432
# 3       Within Tolerance      NaN  1002.430837  -2.430837  63.639432
# 4       Within Tolerance      NaN  1007.176757  -7.176757  63.639432
# 5       Within Tolerance      NaN  1006.597986  -6.597986  63.639432
# 6       Within Tolerance      NaN  1005.903461  -5.903461  63.639432
# 7       Within Tolerance      NaN  1005.440444  -5.440444  63.639432
# 8       Within Tolerance      NaN  1006.713740  -6.713740  63.639432
# 9       Within Tolerance      NaN  1003.472624  -3.472624  63.639432
# 10      Within Tolerance      NaN   509.896979  -9.896979  36.819716
# 11      Within Tolerance      NaN   505.961338  -5.961338  36.819716
# 12      Within Tolerance      NaN   504.572288  -4.572288  36.819716
# 13      Within Tolerance      NaN   504.225026  -4.225026  36.819716
# 14      Within Tolerance      NaN   481.305707  18.694293  36.819716
# 15      Within Tolerance      NaN   496.006482   3.993518  36.819716
# 16      Within Tolerance      NaN   486.283135  13.716865  36.819716
# 17      Within Tolerance      NaN   499.942123   0.057877  36.819716
# 18      Within Tolerance      NaN   495.890728   4.109272  36.819716
# 19      Within Tolerance      NaN   501.215418  -1.215418  36.819716
# 20      Within Tolerance      NaN   302.812826  -2.812826  26.091830
# 21      Within Tolerance      NaN   308.716287  -8.716287  26.091830
# 22      Within Tolerance      NaN   308.253270  -8.253270  26.091830
# 23      Within Tolerance      NaN   307.790254  -7.790254  26.091830
# 24      Within Tolerance      NaN   307.790254  -7.790254  26.091830
# 25      Within Tolerance      NaN   306.516958  -6.516958  26.091830
# 26      Within Tolerance      NaN   309.642320  -9.642320  26.091830
# 27      Within Tolerance      NaN   308.021762  -8.021762  26.091830
# 28      Within Tolerance      NaN   307.211483  -7.211483  26.091830
# 29      Within Tolerance      NaN   305.475171  -5.475171  26.091830
#
#     percent_error
# 0        0.798704
# 1        1.273296
# 2       -0.717676
# 3       -0.243084
# 4       -0.717676
# 5       -0.659799
# 6       -0.590346
# 7       -0.544044
# 8       -0.671374
# 9       -0.347262
# 10      -1.979396
# 11      -1.192268
# 12      -0.914458
# 13      -0.845005
# 14       3.738859
# 15       0.798704
# 16       2.743373
# 17       0.011575
# 18       0.821854
# 19      -0.243084
# 20      -0.937609
# 21      -2.905429
# 22      -2.751090
# 23      -2.596751
# 24      -2.596751
# 25      -2.172319
# 26      -3.214107
# 27      -2.673921
# 28      -2.403828
# 29      -1.825057
#
# [30 rows x 24 columns]

# %%
df_summary_all = pd.DataFrame()
for x in df_experiment['volume'].unique():
    df_experiment_1000 = df_experiment.where(df_experiment['volume'] == x).dropna(how='all')
    df_summary = pd.DataFrame(columns = (f'{x} Actual Volume', f'{x} Absolute Error', f'{x} Percentage Error', f'{x} Actual Time', f'{x} Std Dev', f'{x} Relative Std Dev') )
    data = [df_experiment_1000['act_volume'].mean(), df_experiment_1000['abs_error'].mean(), df_experiment_1000['percent_error'].mean(), df_experiment_1000['act_time'].mean(), df_experiment_1000['act_volume'].std(), (df_experiment_1000['act_volume'].std() / df_experiment_1000['act_volume'].mean() * 100)]
    df_summary.loc[df_experiment['liquid'].iloc[0]] = data
    df_summary_all = pd.concat([df_summary_all, df_summary], axis = 1)

# %%
    def calibration_summary(df):

        if 'volume_transfered' and 'volume_error' and 'time_asp_1000' not in df.columns:
            df['volume_transfered'] = (df['m']/df['density'])*1000
            df['volume_error'] = df['volume_transfered'] - df['volume']
            df['time_asp_1000']=1000/df['aspiration_rate'] + 1000/df['dispense_rate'] + df['delay_aspirate'] + df['delay_dispense']             

        df_summary_all = pd.DataFrame()

        for volume in df['volume'].unique():
            df_experiment_v = df.where(df['volume'] == volume).dropna(how='all')
            df_summary = pd.DataFrame(columns = (f'Mean transfer volume for {volume} µL [µL]', f'Mean transfer volume error of {volume} µL [µL]', f'Mean relative error for transfer of {volume} µL [%]', f'Standard deviation for transfer of {volume} µL [µL]', f'Relative standard deviation for transfer of {volume} µL [%]') )
            data = [df_experiment_v['volume_transfered'].mean(), df_experiment_v['volume_error'].mean(), df_experiment_v['%error'].mean(), df_experiment_v['volume_transfered'].std(), (df_experiment_v['volume_transfered'].std() / df_experiment_v['volume_transfered'].mean() * 100)]
            df_summary.loc[df['liquid'].iloc[0]] = data
            df_summary_all = pd.concat([df_summary_all, df_summary], axis = 1)
        return df_summary_all

# %%
calibration_summary(df_experiment)
# Out:
#                    Mean transfer volume for 1000.0 µL [µL]  \
# Viscosity_std_204                              1002.419261
#
#                    Mean transfer volume error of 1000.0 µL [µL]  \
# Viscosity_std_204                                      2.419261
#
#                    Mean relative error for transfer of 1000.0 µL [%]  \
# Viscosity_std_204                                           0.241926
#
#                    Standard deviation for transfer of 1000.0 µL [µL]  \
# Viscosity_std_204                                           7.003407
#
#                    Relative standard deviation for transfer of 1000.0 µL [%]  \
# Viscosity_std_204                                            0.69865
#
#                    Mean transfer volume for 500.0 µL [µL]  \
# Viscosity_std_204                              498.529922
#
#                    Mean transfer volume error of 500.0 µL [µL]  \
# Viscosity_std_204                                    -1.470078
#
#                    Mean relative error for transfer of 500.0 µL [%]  \
# Viscosity_std_204                                         -0.294016
#
#                    Standard deviation for transfer of 500.0 µL [µL]  \
# Viscosity_std_204                                          8.960264
#
#                    Relative standard deviation for transfer of 500.0 µL [%]  \
# Viscosity_std_204                                           1.797337
#
#                    Mean transfer volume for 300.0 µL [µL]  \
# Viscosity_std_204                              307.223058
#
#                    Mean transfer volume error of 300.0 µL [µL]  \
# Viscosity_std_204                                     7.223058
#
#                    Mean relative error for transfer of 300.0 µL [%]  \
# Viscosity_std_204                                          2.407686
#
#                    Standard deviation for transfer of 300.0 µL [µL]  \
# Viscosity_std_204                                          1.927267
#
#                    Relative standard deviation for transfer of 300.0 µL [%]
# Viscosity_std_204                                           0.627318

# %%
df_summary_all
# Out:
#                    1000.0 Actual Volume  1000.0 Absolute Error  \
# Viscosity_std_204           1002.419261              -2.419261
#
#                    1000.0 Percentage Error  1000.0 Actual Time  \
# Viscosity_std_204                -0.241926           63.639432
#
#                    1000.0 Std Dev  1000.0 Relative Std Dev  \
# Viscosity_std_204        7.003407                  0.69865
#
#                    500.0 Actual Volume  500.0 Absolute Error  \
# Viscosity_std_204           498.529922              1.470078
#
#                    500.0 Percentage Error  500.0 Actual Time  500.0 Std Dev  \
# Viscosity_std_204                0.294016          36.819716       8.960264
#
#                    500.0 Relative Std Dev  300.0 Actual Volume  \
# Viscosity_std_204                1.797337           307.223058
#
#                    300.0 Absolute Error  300.0 Percentage Error  \
# Viscosity_std_204             -7.223058               -2.407686
#
#                    300.0 Actual Time  300.0 Std Dev  300.0 Relative Std Dev
# Viscosity_std_204           26.09183       1.927267                0.627318
